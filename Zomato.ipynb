# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
Df=pd.read_excel(r"C:\Users\sagar\OneDrive\Desktop\vaishu\Dataset\zomato.xlsx")

# %%
Df.dropna(subset=['name'], inplace=True)
Df=Df.dropna(subset=['location'])
Df=Df.drop(columns=['phone'])
Df=Df.dropna(subset=['rest_type'])
Df=Df.dropna(subset=['cuisines'])
Df=Df.dropna(subset=['approx_cost(for two people)'])
Df=Df.dropna(subset=['dish_liked'])

# %%
Df.isnull().sum()
# Out:
# name                            0
# online_order                    0
# book_table                      0
# rate                           29
# votes                           0
# location                        0
# rest_type                       0
# dish_liked                      0
# cuisines                        0
# approx_cost(for two people)     0
# dtype: int64

# %%
Df = Df[Df['online_order'].isin(['Yes', 'No'])]

# %%
Df.tail(30)
# Out:
#                                                     name online_order  \
# 55943                                          Red Rhino          Yes
# 55945                                          Ji Hazoor          Yes
# 55946                                                 HQ           No
# 55948                                     Biere Societee           No
# 55949                            Uno Chicago Bar & Grill           No
# 55950                                  Amoeba Sports Bar          Yes
# 55951                                   One For The Road          Yes
# 55952                                  Whitefield Social          Yes
# 55954             The Whitefield Arms Pub & Microbrewery          Yes
# 55956                                    The Irish House           No
# 55958                           Shizusan Shophouse & Bar          Yes
# 55960         Kava Kitchen & Bar - Fairfield by Marriott           No
# ...

# %%
Df['rate']=Df['rate'].str.replace('/5', '')

# %%
Df['rate']
# Out:
# 0         4.1
# 1         4.1
# 2         3.8
# 3         3.7
# 4         3.8
#          ...
# 55977    3.6
# 55978     NaN
# 55979     NaN
# 55980    4.3
# 55981    3.4
# Name: rate, Length: 51148, dtype: object

# %%
Df = Df.loc[Df["rate"] !='NEW']

# %%
Df['rate']=Df['rate'].astype('float')

# %%
Df['rate'].fillna(Df['rate'].mean(), inplace=True)

# %%
Df.to_excel('ZOMATO_4.xlsx')
